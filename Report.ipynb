# %% [markdown]
# # QC Report

# %% [markdown]
# #.
# REPORT PLAN:
#
# Abstract
#
# Introduction
#
# Hamiltonian, introduce choices of ansatz/optimizers
#
# Some Theory
# Problem we trying to solve
# VQE
# S(π)
# +1 Phase Transition
#
# Experiments
# How we tested ansatz/optimizers (show lots of code and plots)
#
# Analysis
# Ansatz final choice reasoning
# Optimizer final choice reasoning
#
# Further work
# Imaginary Time
# Krylov
#
# Conclusion
